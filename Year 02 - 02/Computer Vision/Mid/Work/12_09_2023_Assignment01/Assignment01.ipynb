# %% [markdown]
# ***Assignment 01***
# | 65011428 Papinwich Asnapetch

# %%
import cv2
from matplotlib import pyplot as plt

# %%
# Load image
pic = cv2.imread('colorobject.png')
# pic = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
# plt.imshow(pic)

# Convert ot grayscale
gray = cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)
# plt.imshow(gray)

fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(pic, cmap= 'gray')
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(gray, cmap= 'gray')

# %%
# Create Histrogram
hist = cv2.calcHist([gray], [0], None, [256], [0, 256])

# Plot the histogram
plt.plot(hist)
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Grayscale Histogram')
plt.show()

# %%
# Task 01: BLUE
ret, blue = cv2.threshold(gray, 50, 255, cv2.THRESH_TOZERO_INV)
ret, blue = cv2.threshold(blue, 10, 255, cv2.THRESH_BINARY)
plt.imshow(blue, cmap= 'gray')

# %%
# Task 02: RED
ret, red = cv2.threshold(gray, 100, 255, cv2.THRESH_TOZERO_INV)
ret, red = cv2.threshold(red, 50, 255, cv2.THRESH_TOZERO)
ret, red = cv2.threshold(red, 10, 255, cv2.THRESH_BINARY)

plt.imshow(red, cmap= 'gray')

# %%
# Task 03: B&R
ret, BR = cv2.threshold(gray, 100, 255, cv2.THRESH_TOZERO_INV)
ret, BR = cv2.threshold(BR, 10, 255, cv2.THRESH_BINARY)

plt.imshow(BR, cmap= 'gray')

# %%
# Task 04: B&R in green
plt.imshow(BR,cmap = plt.cm.colors.ListedColormap(['black', 'green']))
